# %%
class Mylr:
    
  def __init__(self):
      self.m=None
      self.b=None
  def fit(self,x_train,y_train):
      # finding the values of m and b
      num=0
      den=0
      for i in range(x_train.shape[0]):
          num=num+(x_train[i]-x_train.mean())*(y_train[i]-y_train.mean())
          den=den+(x_train[i] - x_train.mean())*(x_train[i] - x_train.mean())
      self.m=num/den 
      self.b = y_train.mean() - self.m * x_train.mean()   
      print(self.m)
      print(self.b)
  def predict(self,x_test):
      if 0<x_test<10:
          return self.m*x_test + self.b
      return 0

# %%
import pandas as pd
df=pd.read_csv('/kaggle/input/datasets/justsimply/placementx/placement_x.csv')

# %%
df.shape
# Out:
# (200, 2)

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
x
# Out:
# array([6.89, 5.12, 7.82, 7.42, 6.94, 7.89, 6.73, 6.75, 6.09, 8.31, 5.32,
#        6.61, 8.94, 6.93, 7.73, 7.25, 6.84, 5.38, 6.94, 7.48, 7.28, 6.85,
#        6.14, 6.19, 6.53, 7.28, 8.31, 5.42, 5.94, 7.15, 7.36, 8.1 , 6.96,
#        6.35, 7.34, 6.87, 5.99, 5.9 , 8.62, 7.43, 9.38, 6.89, 5.95, 7.66,
#        5.09, 7.87, 6.07, 5.84, 8.63, 8.87, 9.58, 9.26, 8.37, 6.47, 6.86,
#        8.2 , 5.84, 6.6 , 6.92, 7.56, 5.61, 5.48, 6.34, 9.16, 7.36, 7.6 ,
#        5.11, 6.51, 7.56, 7.3 , 5.79, 7.47, 7.78, 8.44, 6.85, 6.97, 6.94,
#        8.99, 6.59, 7.18, 7.63, 6.1 , 5.58, 8.44, 4.26, 4.79, 7.61, 8.09,
#        4.73, 6.42, 7.11, 6.22, 7.9 , 6.79, 5.83, 6.63, 7.11, 5.98, 7.69,
#        6.61, 7.95, 6.71, 5.13, 7.05, 7.62, 6.66, 6.13, 6.33, 7.76, 7.77,
#        8.18, 5.42, 8.58, 6.94, 5.84, 8.35, 9.04, 7.12, 7.4 , 7.39, 5.23,
#        6.5 , 5.12, 5.1 , 6.06, 7.33, 5.91, 6.78, 7.93, 7.29, 6.68, 6.37,
#        5.84, 6.05, 7.2 , 6.1 , 5.64, 7.14, 7.91, 7.19, 7.91, 6.76, 6.93,
#        4.85, 6.17, 5.84, 6.07, 5.66, 7.57, 8.28, 6.3 , 6.12, 7.37, 7.94,
#        7.08, 6.98, 7.38, 6.47, 5.95, 8.71, 7.13, 7.3 , 5.53, 8.93, 9.06,
#        8.21, 8.6 , 8.13, 8.65, 9.31, 6.22, 8.01, 6.93, 6.75, 7.32, 7.04,
#        6.29, 7.09, 8.15, 7.14, 6.19, 8.22, 5.88, 7.28, 7.88, 6.31, 7.84,
#        6.26, 7.35, 8.11, 6.19, 7.28, 8.25, 4.57, 7.89, 6.93, 5.89, 7.21,
#        7.63, 6.22])

# %%
y
# Out:
# array([3.26, 1.98, 3.25, 3.67, 3.57, 2.99, 2.6 , 2.48, 2.31, 3.51, 1.86,
#        2.6 , 3.65, 2.89, 3.42, 3.23, 2.35, 2.09, 2.98, 2.83, 3.16, 2.93,
#        2.3 , 2.48, 2.71, 3.65, 3.42, 2.16, 2.24, 3.49, 3.26, 3.89, 3.08,
#        2.73, 3.42, 2.87, 2.84, 2.43, 4.36, 3.33, 4.02, 2.7 , 2.54, 2.76,
#        1.86, 3.58, 2.26, 3.26, 4.09, 4.62, 4.43, 3.79, 4.11, 2.61, 3.09,
#        3.39, 2.74, 1.94, 3.09, 3.31, 2.19, 1.61, 2.09, 4.25, 2.92, 3.81,
#        1.63, 2.89, 2.99, 2.94, 2.35, 3.34, 3.62, 4.03, 3.44, 3.28, 3.15,
#        4.6 , 2.21, 3.  , 3.44, 2.2 , 2.17, 3.49, 1.53, 1.48, 2.77, 3.55,
#        1.48, 2.72, 2.66, 2.14, 4.  , 3.08, 2.42, 2.79, 2.61, 2.84, 3.83,
#        3.24, 4.14, 3.52, 1.37, 3.  , 3.74, 2.82, 2.19, 2.59, 3.54, 4.06,
#        3.76, 2.25, 4.1 , 2.37, 1.87, 4.21, 3.33, 2.99, 2.88, 2.65, 1.73,
#        3.02, 2.01, 2.3 , 2.31, 3.16, 2.6 , 3.11, 3.34, 3.12, 2.49, 2.01,
#        2.48, 2.58, 2.83, 2.6 , 2.1 , 3.13, 3.89, 2.4 , 3.15, 3.18, 3.04,
#        1.54, 2.42, 2.18, 2.46, 2.21, 3.4 , 3.67, 2.73, 2.76, 3.08, 3.99,
#        2.85, 3.09, 3.13, 2.7 , 3.04, 4.08, 2.93, 3.33, 2.55, 3.91, 3.82,
#        4.08, 3.98, 3.6 , 3.52, 4.37, 2.87, 3.76, 2.51, 2.56, 2.99, 3.5 ,
#        3.23, 3.64, 3.63, 3.03, 2.72, 3.89, 2.08, 2.72, 3.14, 3.18, 3.47,
#        2.44, 3.08, 4.06, 2.69, 3.48, 3.75, 1.94, 3.67, 2.46, 2.57, 3.24,
#        3.96, 2.33])

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

# %%
x_train.shape
# Out:
# (160,)

# %%
x_train.mean()
# Out:
# np.float64(7.03425)

# %%
lr=Mylr()
lr.fit(x_train,y_train)
# Out:
# 0.5753843763962532
# -1.0330850496653436

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([2.59183652, 2.38469815, 2.95432868, 3.65629762, 3.43765155,
#        3.94398981, 3.04639018, 2.35592893, 2.32715971, 2.95432868,
#        2.21208283, 4.13962049, 2.56882115, 3.91522059, 1.41805239,
#        3.01762096, 2.9830979 , 3.64478993, 2.7069134 , 3.71383606,
#        2.58608268, 2.96008252, 2.66088265, 2.22359052, 2.59759037,
#        1.75752918, 2.54580577, 2.36743661, 3.50669768, 2.40771352,
#        3.19023627, 3.10392862, 1.89562143, 3.4434054 , 3.15571321,
#        1.72300611, 3.73109759, 2.45949812, 3.34559005, 3.9037129 ])

# %%
y_pred.shape
# Out:
# (40,)

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(f'R2 SCORE:{r2}')
# Out:
# R2 SCORE:0.7415961128378261

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test,color="blue",label='Actual values')
plt.plot(x_test,y_pred,color='red',label="Predicted line")
